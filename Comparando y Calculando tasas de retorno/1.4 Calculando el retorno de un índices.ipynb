# %% [markdown]
# ### Cargando librerías

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pandas_datareader import data as wb

# %% [markdown]
# ### Cargando los datos

# %%
tickers = ['^GSPC', '^IXIC', '^GDAXI', '^BVSP']
ind_data = pd.DataFrame()
for t in tickers:
    ind_data[t]= wb.DataReader(t, data_source ='yahoo', start ='1997-1-1')['Adj Close']

# %%
ind_data.head()
# Out:
#                  ^GSPC        ^IXIC       ^GDAXI        ^BVSP
# Date
# 1997-01-02  737.010010  1280.699951  2820.810059  6955.500000
# 1997-01-03  748.030029  1310.680054  2863.260010  6997.799805
# 1997-01-06  747.650024  1316.400024  2890.199951  7159.500000
# 1997-01-07  753.229980  1327.729980  2876.340088  7159.500000
# 1997-01-08  748.409973  1320.349976  2904.080078  7427.000000

# %%
ind_data.tail()
# Out:
#                   ^GSPC         ^IXIC        ^GDAXI
# Date
# 2022-02-16  4475.009766  14124.089844  15396.070312
# 2022-02-17  4380.259766  13716.719727  15267.629883
# 2022-02-18  4348.870117  13548.070312  15042.509766
# 2022-02-22  4304.759766  13381.519531  14693.000000
# 2022-02-23  4297.910156  13327.955078  14631.360352

# %%
(ind_data / ind_data.iloc[0] * 100).plot(figsize=(20,5), title ='Normalizado')
plt.show()

# %%
ind_retornos = (ind_data/ind_data.shift(1))-1
ind_retornos.tail()
# Out:
#                ^GSPC     ^IXIC    ^GDAXI     ^BVSP
# Date
# 2022-02-16  0.000881 -0.001108 -0.001080  0.004544
# 2022-02-17 -0.021173 -0.028842 -0.008342 -0.014351
# 2022-02-18 -0.007166 -0.012295 -0.014745 -0.006694
# 2022-02-22 -0.010143 -0.012293 -0.023235  0.001100
# 2022-02-23 -0.001027 -0.003630 -0.004195 -0.002251

# %%
ind_ret_anual = ind_retornos.mean()*250
ind_ret_anual
# Out:
# ^GSPC     0.088676
# ^IXIC     0.123770
# ^GDAXI    0.077386
# ^BVSP     0.145898
# dtype: float64

# %%
tickers = ['PG', '^GSPC', '^DJI']
data_2=pd.DataFrame()
for t in tickers:
    data_2[t] = wb.DataReader(t, data_source='yahoo', start='2007-1-1')['Adj Close']

# %%
data_2.tail()
# Out:
#                     PG        ^GSPC          ^DJI
# Date
# 2022-02-16  158.009995  4475.009766  34934.269531
# 2022-02-17  159.820007  4380.259766  34312.031250
# 2022-02-18  159.899994  4348.870117  34079.179688
# 2022-02-22  157.929993  4304.759766  33596.609375
# 2022-02-23  157.179993  4285.810059  33525.789062

# %%
(data_2 /data_2.iloc[0]*100).plot(figsize=(20,5))
plt.show()
